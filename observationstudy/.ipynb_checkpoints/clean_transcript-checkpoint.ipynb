# %%
import pandas as pd
import numpy as np 
import re
import nltk
#from transformers import BertTokenizer

# %% [markdown]
# ### Create a setence level data set using the filename, speaker, and timestamp as labels

# %%
file_path = '/Users/steffenerickson/Box Sync/ECR Observation Data/2023-2024 Final Data/Quant Team - Results'
df = pd.read_csv(f'{file_path}/transcripts.csv')

# %%
df_lines_split = df['text'].str.split(r'\\n').apply(pd.Series).stack().to_frame('line_str')
df_lines_split.reset_index(drop=True, inplace=True)
df_lines_split['filename'] = df['filename'].repeat(df_lines_split.shape[0] // len(df)).reset_index(drop=True)
df_cleaned = df_lines_split[df_lines_split['line_str'].str.strip() != ""]

# %%
def is_teacher_timestamp(text):
    return bool(re.search(r'teacher \d+.*\d+:\d+', text, re.IGNORECASE))
def is_transcribed_by_otter(text):
    return bool(re.search(r'transcribed by https://otter\.ai', text, re.IGNORECASE))

# %%
df_cleaned = df_cleaned.copy()
df_cleaned.loc[:, 'is_teacher_timestamp'] = df_cleaned['line_str'].apply(is_teacher_timestamp)
df_cleaned.loc[:, 'firstrow'] = df_cleaned.groupby('filename')['is_teacher_timestamp'].transform(
    lambda x: x.idxmax() == x.index).fillna(False).astype(int)
df_cleaned.loc[:, 'is_transcribed_by_otter'] = df_cleaned['line_str'].apply(is_transcribed_by_otter)
df_cleaned.loc[:, 'lastrow'] = df_cleaned['is_transcribed_by_otter'].apply(lambda x: 1 if x else 0)

# %%
def keep_between_ones(group):
    start_idx = group['firstrow'].idxmax()  # First occurrence of 1 in the second column
    end_idx = group['lastrow'].idxmax()    # First occurrence of 1 in the third column
    return group.loc[start_idx:end_idx-1]
df_chopped = df_cleaned.groupby('filename', group_keys=False).apply(keep_between_ones)
df_chopped = df_chopped.drop(['firstrow', 'lastrow','is_teacher_timestamp','is_transcribed_by_otter'], axis=1)

# %%
# Define a function to classify the rows based on the 'line_str'
def classify_line_str(line):
    if re.match(r'Teacher.*\d{2}:\d{2}', line):
        return 1
    elif re.match(r'.*\d{2}:\d{2}', line):
        return 2
    else:
        return np.nan
df_chopped['classification'] = df_chopped['line_str'].apply(classify_line_str)

# %%
# Define a function to extract the person (text before the timestamp) and timestamp
def extract_person_and_timestamp(line):
    # Use regex to match the format "[text] [timestamp]"
    match = re.search(r'(.+?)\s+(\d{2}:\d{2})', line)  # Adjusted to find any text before the timestamp
    if match:
        return match.group(1).strip(), match.group(2)
    else:
        return np.nan, np.nan
df_chopped['person'], df_chopped['timestamp'] = zip(*df_chopped.apply(
    lambda row: extract_person_and_timestamp(row['line_str']) if pd.notna(row['classification']) else (np.nan, np.nan), axis=1))

# %%
df_chopped['keep'] = df_chopped['classification'].apply(lambda x: 1 if pd.isna(x) else 0)
df_chopped['classification'] = df_chopped['classification'].ffill()
df_chopped['person'] = df_chopped['person'].ffill()
df_chopped['timestamp'] = df_chopped['timestamp'].ffill()
df_filtered = df_chopped[df_chopped['keep'] == 1]
df_filtered = df_filtered.drop(['keep'], axis=1)
df_filtered.reset_index(drop=True, inplace=True)

# %%
df_sentences = df_filtered.line_str.apply(lambda x: pd.Series(nltk.sent_tokenize(x))).stack().to_frame('sent_str')
df_sentences = df_sentences.reset_index(level=1, drop=True)
variables = ['filename', 'classification', 'person', 'timestamp','line_str']
for var in variables:
    df_sentences[var] = df_filtered[var].repeat(df_sentences.groupby(level=0).size()).values

# %%
#df_speaker = df_sentences[df_sentences['person'].str.contains('speaker', case=False, na=False)]

# %%
## Apply the conditions to locate the rows to be updated
#condition = (
#    (df_sentences['filename'] == "01_0101_G4_L03_transcript.txt") & 
#    (df_sentences['person'].str.contains('speaker', case=False, na=False))
#)
## Update the 'person' column
#df_sentences.loc[condition, 'person'] = "Teacher 01_0101"
## Update the 'classification' column to 1 for the same rows
#df_sentences.loc[condition, 'classification'] = 1

# %% [markdown]
# ### Tokenize Sentences

# %%
keep_whitespace = True
if keep_whitespace:
    # Return a tokenized copy of text
    # using NLTK's recommended word tokenizer.
    df_tokens = df_sentences.sent_str\
            .apply(lambda x: pd.Series(nltk.pos_tag(nltk.word_tokenize(x))))\
            .stack()\
            .to_frame('pos_tuple')
else:
    # Tokenize a string on whitespace (space, tab, newline).
    # In general, users should use the string ``split()`` method instead.
    # Returns fewer tokens.
    df_tokens = SENTS.sent_str\
            .apply(lambda x: pd.Series(nltk.pos_tag(nltk.WhitespaceTokenizer().tokenize(x))))\
            .stack()\
            .to_frame('pos_tuple')
df_tokens['pos'] = df_tokens.pos_tuple.apply(lambda x: x[1])
df_tokens['token_str'] = df_tokens.pos_tuple.apply(lambda x: x[0])
df_tokens['term_str'] = df_tokens.token_str.str.lower().str.replace(r"\W+", "", regex=True)
df_tokens['pos_group'] = df_tokens.pos.str[:2]

# %%
variables = ['filename', 'classification', 'person', 'timestamp','sent_str','line_str']
repeat_counts = df_sentences['sent_str'].apply(lambda x: len(nltk.word_tokenize(x)))
for var in variables:
    df_tokens[var] = np.repeat(df_sentences[var].values, repeat_counts)

# %%
df_tokens = df_tokens[df_tokens.term_str != '']

# %%
df_tokens.head(50)
# Out:
#              pos_tuple  pos   token_str    term_str pos_group  \
# 0 0         (You, PRP)  PRP         You         you        PR
#   1           (ca, MD)   MD          ca          ca        MD
#   2          (n't, RB)   RB         n't          nt        RB
#   3          (see, VB)   VB         see         see        VB
#   4        (those, DT)   DT       those       those        DT
#   5           (up, IN)   IN          up          up        IN
#   6        (there, RB)   RB       there       there        RB
#   0        (Which, JJ)   JJ       Which       which        JJ
#   1        (ones, NNS)  NNS        ones        ones        NN
#   2         (are, VBP)  VBP         are         are        VB
#   3         (you, PRP)  PRP         you         you        PR
#   4       (going, VBG)  VBG       going       going        VB
#   5           (to, TO)   TO          to          to        TO
#   6          (put, VB)   VB         put         put        VB
#   7         (down, RP)   RP        down        down        RP
# 1 0        (Those, DT)   DT       Those       those        DT
#   1          (two, CD)   CD         two         two        CD
#   2        (three, CD)   CD       three       three        CD
# 2 0          (Do, VBP)  VBP          Do          do        VB
#   1          (we, PRP)  PRP          we          we        PR
#   2          (hit, VB)   VB         hit         hit        VB
#   3        (done, VBN)  VBN        done        done        VB
# 3 0          (Yep, NN)   NN         Yep         yep        NN
#   0          (He, PRP)  PRP          He          he        PR
#   1          ('s, VBZ)  VBZ          's           s        VB
#   2         (got, VBD)  VBD         got         got        VB
#   3        (them, PRP)  PRP        them        them        PR
#   0         (Yeah, UH)   UH        Yeah        yeah        UH
#   2         (yeah, UH)   UH        yeah        yeah        UH
#   0           (If, IN)   IN          If          if        IN
#   1  (you_______, VBN)  VBN  you_______  you_______        VB
#   2         (you, PRP)  PRP         you         you        PR
#   3          (can, MD)   MD         can         can        MD
#   4          (hit, VB)   VB         hit         hit        VB
#   5        (done, VBN)  VBN        done        done        VB
#   0          (Yes, UH)   UH         Yes         yes        UH
#   0          (One, CD)   CD         One         one        CD
#   1        (more, JJR)  JJR        more        more        JJ
#   0          (The, DT)   DT         The         the        DT
#   1     (biggest, JJS)  JJS     biggest     biggest        JJ
#   2          (one, NN)   NN         one         one        NN
# 4 0      (Jupiter, NN)   NN     Jupiter     jupiter        NN
# 5 0          (Yep, NN)   NN         Yep         yep        NN
#   0         (That, DT)   DT        That        that        DT
#   1          ('s, VBZ)  VBZ          's           s        VB
#   2        (right, JJ)   JJ       right       right        JJ
#   0          (Gas, VB)   VB         Gas         gas        VB
#   1         (what, WP)   WP        what        what        WP
#   0         (Gas, NNP)  NNP         Gas         gas        NN
#   2         (what, WP)   WP        what        what        WP
#
#                           filename  classification                person  \
# 0 0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   3  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   4  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   5  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   6  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   3  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   4  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   5  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   6  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   7  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
# 1 0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#   1  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#   2  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 2 0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#   1  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#   2  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#   3  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 3 0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   3  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   3  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   4  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   5  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
# 4 0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 5 0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2  01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#
#     timestamp                               sent_str  \
# 0 0     45:33          You can't see those up there?
#   1     45:33          You can't see those up there?
#   2     45:33          You can't see those up there?
#   3     45:33          You can't see those up there?
#   4     45:33          You can't see those up there?
#   5     45:33          You can't see those up there?
#   6     45:33          You can't see those up there?
#   0     45:33  Which ones are you going to put down?
#   1     45:33  Which ones are you going to put down?
#   2     45:33  Which ones are you going to put down?
#   3     45:33  Which ones are you going to put down?
#   4     45:33  Which ones are you going to put down?
#   5     45:33  Which ones are you going to put down?
#   6     45:33  Which ones are you going to put down?
#   7     45:33  Which ones are you going to put down?
# 1 0     45:41                       Those two three.
#   1     45:41                       Those two three.
#   2     45:41                       Those two three.
# 2 0     45:43                        Do we hit done?
#   1     45:43                        Do we hit done?
#   2     45:43                        Do we hit done?
#   3     45:43                        Do we hit done?
# 3 0     45:44                                   Yep.
#   0     45:44                         He's got them.
#   1     45:44                         He's got them.
#   2     45:44                         He's got them.
#   3     45:44                         He's got them.
#   0     45:44                            Yeah, yeah.
#   2     45:44                            Yeah, yeah.
#   0     45:44        If you_______ you can hit done.
#   1     45:44        If you_______ you can hit done.
#   2     45:44        If you_______ you can hit done.
#   3     45:44        If you_______ you can hit done.
#   4     45:44        If you_______ you can hit done.
#   5     45:44        If you_______ you can hit done.
#   0     45:44                                   Yes.
#   0     45:44                              One more.
#   1     45:44                              One more.
#   0     45:44                       The biggest one.
#   1     45:44                       The biggest one.
#   2     45:44                       The biggest one.
# 4 0     45:54                               Jupiter?
# 5 0     45:55                                   Yep.
#   0     45:55                          That's right.
#   1     45:55                          That's right.
#   2     45:55                          That's right.
#   0     45:55                              Gas what?
#   1     45:55                              Gas what?
#   0     45:55            Gas, what meant really big.
#   2     45:55            Gas, what meant really big.
#
#                                               line_str
# 0 0  You can't see those up there? Which ones are y...
#   1  You can't see those up there? Which ones are y...
#   2  You can't see those up there? Which ones are y...
#   3  You can't see those up there? Which ones are y...
#   4  You can't see those up there? Which ones are y...
#   5  You can't see those up there? Which ones are y...
#   6  You can't see those up there? Which ones are y...
#   0  You can't see those up there? Which ones are y...
#   1  You can't see those up there? Which ones are y...
#   2  You can't see those up there? Which ones are y...
#   3  You can't see those up there? Which ones are y...
#   4  You can't see those up there? Which ones are y...
#   5  You can't see those up there? Which ones are y...
#   6  You can't see those up there? Which ones are y...
#   7  You can't see those up there? Which ones are y...
# 1 0                                  Those two three.
#   1                                  Those two three.
#   2                                  Those two three.
# 2 0                                    Do we hit done?
#   1                                    Do we hit done?
#   2                                    Do we hit done?
#   3                                    Do we hit done?
# 3 0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
#   3  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
#   3  Yep. He's got them. Yeah, yeah. If you_______ ...
#   4  Yep. He's got them. Yeah, yeah. If you_______ ...
#   5  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
# 4 0                                           Jupiter?
# 5 0  Yep. That's right. Gas what? Gas, what meant r...
#   0  Yep. That's right. Gas what? Gas, what meant r...
#   1  Yep. That's right. Gas what? Gas, what meant r...
#   2  Yep. That's right. Gas what? Gas, what meant r...
#   0  Yep. That's right. Gas what? Gas, what meant r...
#   1  Yep. That's right. Gas what? Gas, what meant r...
#   0  Yep. That's right. Gas what? Gas, what meant r...
#   2  Yep. That's right. Gas what? Gas, what meant r...

# %% [markdown]
# ### Vocab Tables

# %%
# Teacher Vocab 
df_tokens_teacher = df_tokens[df_tokens['classification'] == 1]
vocab_teacher = df_tokens_teacher['term_str'].value_counts().to_frame('n')
vocab_teacher.index.name = 'term_str'
vocab_teacher['p'] = vocab_teacher['n'] / vocab_teacher['n'].sum()  # Probability of each term
vocab_teacher['i'] = -np.log2(vocab_teacher['p'])  # Information content
vocab_teacher['n_chars'] = vocab_teacher.index.str.len()  # Number of characters in each term

# %%
#Student Vocab
df_tokens_student = df_tokens[df_tokens['classification'] == 2]
vocab_student = df_tokens_student['term_str'].value_counts().to_frame('n')
vocab_student.index.name = 'term_str'
vocab_student['p'] = vocab_student['n'] / vocab_student['n'].sum()  # Probability of each term
vocab_student['i'] = -np.log2(vocab_student['p'])  # Information content
vocab_student['n_chars'] = vocab_student.index.str.len()  # Number of characters in each term
vocab_student.head()
# Out:
#              n         p         i  n_chars
# term_str
# the       1139  0.040721  4.618092        3
# it         952  0.034035  4.876826        2
# i          797  0.028494  5.133208        1
# you        573  0.020486  5.609253        3
# and        561  0.020056  5.639787        3

# %%
vocab_teacher.head(20)
# Out:
#              n         p         i  n_chars
# term_str
# you       5848  0.043253  4.531072        3
# the       4316  0.031922  4.969321        3
# to        3658  0.027055  5.207960        2
# it        3314  0.024511  5.350442        2
# i         2816  0.020827  5.585368        1
# that      2486  0.018387  5.765189        4
# and       2484  0.018372  5.766350        3
# s         2101  0.015539  6.007939        1
# a         2093  0.015480  6.013443        1
# we        2075  0.015347  6.025904        2
# so        2029  0.015007  6.058246        2
# what      1825  0.013498  6.211119        4
# okay      1796  0.013283  6.234228        4
# your      1759  0.013010  6.264260        4
# of        1653  0.012226  6.353929        2
# do        1595  0.011797  6.405459        2
# is        1541  0.011397  6.455149        2
# re        1466  0.010843  6.527130        2
# in        1302  0.009630  6.698286        2
# right     1273  0.009415  6.730783        5

# %%
vocab_student.head(20)
# Out:
#              n         p         i  n_chars
# term_str
# the       1139  0.040721  4.618092        3
# it         952  0.034035  4.876826        2
# i          797  0.028494  5.133208        1
# you        573  0.020486  5.609253        3
# and        561  0.020056  5.639787        3
# to         517  0.018483  5.757624        2
# a          516  0.018448  5.760417        1
# s          460  0.016446  5.926154        1
# like       444  0.015874  5.977228        4
# that       401  0.014336  6.124186        4
# we         384  0.013729  6.186682        2
# of         335  0.011977  6.383627        2
# do         323  0.011548  6.436254        2
# is         295  0.010547  6.567073        2
# so         287  0.010261  6.606737        2
# in         252  0.009009  6.794364        2
# what       223  0.007973  6.970744        4
# can        221  0.007901  6.983742        3
# this       216  0.007722  7.016757        4
# one        216  0.007722  7.016757        3

# %%
df_tokens_student.head(50)
# Out:
#              pos_tuple  pos  token_str   term_str pos_group  \
# 1  0       (Those, DT)   DT      Those      those        DT
#    1         (two, CD)   CD        two        two        CD
#    2       (three, CD)   CD      three      three        CD
# 2  0         (Do, VBP)  VBP         Do         do        VB
#    1         (we, PRP)  PRP         we         we        PR
#    2         (hit, VB)   VB        hit        hit        VB
#    3       (done, VBN)  VBN       done       done        VB
# 4  0     (Jupiter, NN)   NN    Jupiter    jupiter        NN
# 6  0     (Giants, NNS)  NNS     Giants     giants        NN
# 8  0    (Neptune, NNP)  NNP    Neptune    neptune        NN
# 10 0    (Jupiter, NNP)  NNP    Jupiter    jupiter        NN
#    2     (Saturn, NNP)  NNP     Saturn     saturn        NN
#    4     (Uranus, NNP)  NNP     Uranus     uranus        NN
#    6    (Neptune, NNP)  NNP    Neptune    neptune        NN
# 12 0        (Gas, NNP)  NNP        Gas        gas        NN
#    1     (giants, NNS)  NNS     giants     giants        NN
# 18 0    (Neptune, NNP)  NNP    Neptune    neptune        NN
# 20 0          (So, IN)   IN         So         so        IN
#    1       (these, DT)   DT      these      these        DT
#    2        (are, VBP)  VBP        are        are        VB
#    3         (n't, RB)   RB        n't         nt        RB
#    4         (the, DT)   DT        the        the        DT
#    5    (planets, NNS)  NNS    planets    planets        NN
# 22 0       (Does, VBZ)  VBZ       Does       does        VB
#    1         (it, PRP)  PRP         it         it        PR
#    2        (mean, VB)   VB       mean       mean        VB
#    3         (it, PRP)  PRP         it         it        PR
#    4         ('s, VBZ)  VBZ         's          s        VB
#    5          (in, IN)   IN         in         in        IN
#    6         (the, DT)   DT        the        the        DT
#    7      (middle, NN)   NN     middle     middle        NN
# 24 0         (Yay, NN)   NN        Yay        yay        NN
#    1      (varied, JJ)   JJ     varied     varied        JJ
#    2  (responses, NNS)  NNS  responses  responses        NN
# 27 0         (It, PRP)  PRP         It         it        PR
#    1         ('s, VBZ)  VBZ         's          s        VB
#    2          (in, IN)   IN         in         in        IN
#    3       (order, NN)   NN      order      order        NN
# 29 0         (Who, WP)   WP        Who        who        WP
#    1        (are, VBP)  VBP        are        are        VB
#    2         (we, PRP)  PRP         we         we        PR
#    3    (waiting, VBG)  VBG    waiting    waiting        VB
#    4          (on, IN)   IN         on         on        IN
# 31 0        (Yay, NNP)  NNP        Yay        yay        NN
#    2      (varied, JJ)   JJ     varied     varied        JJ
#    3  (responses, NNS)  NNS  responses  responses        NN
# 33 0     (Jupiter, NN)   NN    Jupiter    jupiter        NN
# 35 0          (I, PRP)  PRP          I          i        PR
#    1         ('m, VBP)  VBP         'm          m        VB
#    2     (trying, VBG)  VBG     trying     trying        VB
#
#                            filename  classification                person  \
# 1  0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 2  0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 4  0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 6  0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 8  0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 10 0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    4  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    6  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 12 0  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L03_transcript.txt             2.0  Unidentified Student
# 18 0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 20 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    4  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    5  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 22 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    4  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    5  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    6  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    7  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 24 0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    1  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    2  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 27 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 29 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    4  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 31 0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    2  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    3  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 33 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 35 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#
#      timestamp                                           sent_str  \
# 1  0     45:41                                   Those two three.
#    1     45:41                                   Those two three.
#    2     45:41                                   Those two three.
# 2  0     45:43                                    Do we hit done?
#    1     45:43                                    Do we hit done?
#    2     45:43                                    Do we hit done?
#    3     45:43                                    Do we hit done?
# 4  0     45:54                                           Jupiter?
# 6  0     46:05                                            Giants?
# 8  0     46:20                                           Neptune?
# 10 0     46:21                  Jupiter, Saturn, Uranus, Neptune.
#    2     46:21                  Jupiter, Saturn, Uranus, Neptune.
#    4     46:21                  Jupiter, Saturn, Uranus, Neptune.
#    6     46:21                  Jupiter, Saturn, Uranus, Neptune.
# 12 0     46:36                                        Gas giants.
#    1     46:36                                        Gas giants.
# 18 0     32:07                                           Neptune.
# 20 0     32:19                       So these aren't the planets?
#    1     32:19                       So these aren't the planets?
#    2     32:19                       So these aren't the planets?
#    3     32:19                       So these aren't the planets?
#    4     32:19                       So these aren't the planets?
#    5     32:19                       So these aren't the planets?
# 22 0     32:40                   Does it mean it's in the middle?
#    1     32:40                   Does it mean it's in the middle?
#    2     32:40                   Does it mean it's in the middle?
#    3     32:40                   Does it mean it's in the middle?
#    4     32:40                   Does it mean it's in the middle?
#    5     32:40                   Does it mean it's in the middle?
#    6     32:40                   Does it mean it's in the middle?
#    7     32:40                   Does it mean it's in the middle?
# 24 0     32:57                                               Yay!
#    1     32:57                                 (varied responses)
#    2     32:57                                 (varied responses)
# 27 0     33:50                                     It's in order.
#    1     33:50                                     It's in order.
#    2     33:50                                     It's in order.
#    3     33:50                                     It's in order.
# 29 0     33:54                             Who are we waiting on?
#    1     33:54                             Who are we waiting on?
#    2     33:54                             Who are we waiting on?
#    3     33:54                             Who are we waiting on?
#    4     33:54                             Who are we waiting on?
# 31 0     34:17                             Yay (varied responses)
#    2     34:17                             Yay (varied responses)
#    3     34:17                             Yay (varied responses)
# 33 0     34:20                                           Jupiter!
# 35 0     34:51  I'm trying to think of the song where it sings...
#    1     34:51  I'm trying to think of the song where it sings...
#    2     34:51  I'm trying to think of the song where it sings...
#
#                                                line_str
# 1  0                                  Those two three.
#    1                                  Those two three.
#    2                                  Those two three.
# 2  0                                    Do we hit done?
#    1                                    Do we hit done?
#    2                                    Do we hit done?
#    3                                    Do we hit done?
# 4  0                                           Jupiter?
# 6  0                                           Giants?
# 8  0                                          Neptune?
# 10 0                 Jupiter, Saturn, Uranus, Neptune.
#    2                 Jupiter, Saturn, Uranus, Neptune.
#    4                 Jupiter, Saturn, Uranus, Neptune.
#    6                 Jupiter, Saturn, Uranus, Neptune.
# 12 0                                       Gas giants.
#    1                                       Gas giants.
# 18 0                                           Neptune.
# 20 0                      So these aren't the planets?
#    1                      So these aren't the planets?
#    2                      So these aren't the planets?
#    3                      So these aren't the planets?
#    4                      So these aren't the planets?
#    5                      So these aren't the planets?
# 22 0                  Does it mean it's in the middle?
#    1                  Does it mean it's in the middle?
#    2                  Does it mean it's in the middle?
#    3                  Does it mean it's in the middle?
#    4                  Does it mean it's in the middle?
#    5                  Does it mean it's in the middle?
#    6                  Does it mean it's in the middle?
#    7                  Does it mean it's in the middle?
# 24 0                            Yay! (varied responses)
#    1                            Yay! (varied responses)
#    2                            Yay! (varied responses)
# 27 0                                    It's in order.
#    1                                    It's in order.
#    2                                    It's in order.
#    3                                    It's in order.
# 29 0                            Who are we waiting on?
#    1                            Who are we waiting on?
#    2                            Who are we waiting on?
#    3                            Who are we waiting on?
#    4                            Who are we waiting on?
# 31 0                             Yay (varied responses)
#    2                             Yay (varied responses)
#    3                             Yay (varied responses)
# 33 0                                          Jupiter!
# 35 0  I'm trying to think of the song where it sings...
#    1  I'm trying to think of the song where it sings...
#    2  I'm trying to think of the song where it sings...

# %%
df_tokens_teacher.head(50)
# Out:
#              pos_tuple  pos   token_str    term_str pos_group  \
# 0 0         (You, PRP)  PRP         You         you        PR
#   1           (ca, MD)   MD          ca          ca        MD
#   2          (n't, RB)   RB         n't          nt        RB
#   3          (see, VB)   VB         see         see        VB
#   4        (those, DT)   DT       those       those        DT
#   5           (up, IN)   IN          up          up        IN
#   6        (there, RB)   RB       there       there        RB
#   0        (Which, JJ)   JJ       Which       which        JJ
#   1        (ones, NNS)  NNS        ones        ones        NN
#   2         (are, VBP)  VBP         are         are        VB
#   3         (you, PRP)  PRP         you         you        PR
#   4       (going, VBG)  VBG       going       going        VB
#   5           (to, TO)   TO          to          to        TO
#   6          (put, VB)   VB         put         put        VB
#   7         (down, RP)   RP        down        down        RP
# 3 0          (Yep, NN)   NN         Yep         yep        NN
#   0          (He, PRP)  PRP          He          he        PR
#   1          ('s, VBZ)  VBZ          's           s        VB
#   2         (got, VBD)  VBD         got         got        VB
#   3        (them, PRP)  PRP        them        them        PR
#   0         (Yeah, UH)   UH        Yeah        yeah        UH
#   2         (yeah, UH)   UH        yeah        yeah        UH
#   0           (If, IN)   IN          If          if        IN
#   1  (you_______, VBN)  VBN  you_______  you_______        VB
#   2         (you, PRP)  PRP         you         you        PR
#   3          (can, MD)   MD         can         can        MD
#   4          (hit, VB)   VB         hit         hit        VB
#   5        (done, VBN)  VBN        done        done        VB
#   0          (Yes, UH)   UH         Yes         yes        UH
#   0          (One, CD)   CD         One         one        CD
#   1        (more, JJR)  JJR        more        more        JJ
#   0          (The, DT)   DT         The         the        DT
#   1     (biggest, JJS)  JJS     biggest     biggest        JJ
#   2          (one, NN)   NN         one         one        NN
# 5 0          (Yep, NN)   NN         Yep         yep        NN
#   0         (That, DT)   DT        That        that        DT
#   1          ('s, VBZ)  VBZ          's           s        VB
#   2        (right, JJ)   JJ       right       right        JJ
#   0          (Gas, VB)   VB         Gas         gas        VB
#   1         (what, WP)   WP        what        what        WP
#   0         (Gas, NNP)  NNP         Gas         gas        NN
#   2         (what, WP)   WP        what        what        WP
#   3       (meant, VBD)  VBD       meant       meant        VB
#   4       (really, RB)   RB      really      really        RB
#   5          (big, JJ)   JJ         big         big        JJ
# 7 0          (Put, VB)   VB         Put         put        VB
#   1         (that, DT)   DT        that        that        DT
#   2         (word, NN)   NN        word        word        NN
#   3           (in, IN)   IN          in          in        IN
#   4        (there, RB)   RB       there       there        RB
#
#                           filename  classification           person timestamp  \
# 0 0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   3  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   4  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   5  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   6  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   3  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   4  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   5  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   6  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
#   7  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:33
# 3 0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   3  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   3  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   4  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   5  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:44
# 5 0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   3  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   4  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
#   5  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     45:55
# 7 0  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     46:05
#   1  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     46:05
#   2  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     46:05
#   3  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     46:05
#   4  01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101     46:05
#
#                                   sent_str  \
# 0 0          You can't see those up there?
#   1          You can't see those up there?
#   2          You can't see those up there?
#   3          You can't see those up there?
#   4          You can't see those up there?
#   5          You can't see those up there?
#   6          You can't see those up there?
#   0  Which ones are you going to put down?
#   1  Which ones are you going to put down?
#   2  Which ones are you going to put down?
#   3  Which ones are you going to put down?
#   4  Which ones are you going to put down?
#   5  Which ones are you going to put down?
#   6  Which ones are you going to put down?
#   7  Which ones are you going to put down?
# 3 0                                   Yep.
#   0                         He's got them.
#   1                         He's got them.
#   2                         He's got them.
#   3                         He's got them.
#   0                            Yeah, yeah.
#   2                            Yeah, yeah.
#   0        If you_______ you can hit done.
#   1        If you_______ you can hit done.
#   2        If you_______ you can hit done.
#   3        If you_______ you can hit done.
#   4        If you_______ you can hit done.
#   5        If you_______ you can hit done.
#   0                                   Yes.
#   0                              One more.
#   1                              One more.
#   0                       The biggest one.
#   1                       The biggest one.
#   2                       The biggest one.
# 5 0                                   Yep.
#   0                          That's right.
#   1                          That's right.
#   2                          That's right.
#   0                              Gas what?
#   1                              Gas what?
#   0            Gas, what meant really big.
#   2            Gas, what meant really big.
#   3            Gas, what meant really big.
#   4            Gas, what meant really big.
#   5            Gas, what meant really big.
# 7 0        Put that word in there with it.
#   1        Put that word in there with it.
#   2        Put that word in there with it.
#   3        Put that word in there with it.
#   4        Put that word in there with it.
#
#                                               line_str
# 0 0  You can't see those up there? Which ones are y...
#   1  You can't see those up there? Which ones are y...
#   2  You can't see those up there? Which ones are y...
#   3  You can't see those up there? Which ones are y...
#   4  You can't see those up there? Which ones are y...
#   5  You can't see those up there? Which ones are y...
#   6  You can't see those up there? Which ones are y...
#   0  You can't see those up there? Which ones are y...
#   1  You can't see those up there? Which ones are y...
#   2  You can't see those up there? Which ones are y...
#   3  You can't see those up there? Which ones are y...
#   4  You can't see those up there? Which ones are y...
#   5  You can't see those up there? Which ones are y...
#   6  You can't see those up there? Which ones are y...
#   7  You can't see those up there? Which ones are y...
# 3 0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
#   3  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
#   3  Yep. He's got them. Yeah, yeah. If you_______ ...
#   4  Yep. He's got them. Yeah, yeah. If you_______ ...
#   5  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   0  Yep. He's got them. Yeah, yeah. If you_______ ...
#   1  Yep. He's got them. Yeah, yeah. If you_______ ...
#   2  Yep. He's got them. Yeah, yeah. If you_______ ...
# 5 0  Yep. That's right. Gas what? Gas, what meant r...
#   0  Yep. That's right. Gas what? Gas, what meant r...
#   1  Yep. That's right. Gas what? Gas, what meant r...
#   2  Yep. That's right. Gas what? Gas, what meant r...
#   0  Yep. That's right. Gas what? Gas, what meant r...
#   1  Yep. That's right. Gas what? Gas, what meant r...
#   0  Yep. That's right. Gas what? Gas, what meant r...
#   2  Yep. That's right. Gas what? Gas, what meant r...
#   3  Yep. That's right. Gas what? Gas, what meant r...
#   4  Yep. That's right. Gas what? Gas, what meant r...
#   5  Yep. That's right. Gas what? Gas, what meant r...
# 7 0  Put that word in there with it. So you wrote t...
#   1  Put that word in there with it. So you wrote t...
#   2  Put that word in there with it. So you wrote t...
#   3  Put that word in there with it. So you wrote t...
#   4  Put that word in there with it. So you wrote t...

# %%
df_tokens.to_csv(f'{file_path}/df_tokens.csv', index=False)
