# %%
import pandas as pd
import numpy as np 
import re
import nltk
#from transformers import BertTokenizer

# %% [markdown]
# ### Create a setence level data set using the filename, speaker, and timestamp as labels

# %%
file_path = '/Users/steffenerickson/Box Sync/ECR Observation Data/2023-2024 Final Data/Quant Team - Results'
df = pd.read_csv(f'{file_path}/transcripts.csv')

# %%
df_lines_split = df['text'].str.split(r'\\n').apply(pd.Series).stack().to_frame('line_str')
df_lines_split.reset_index(drop=True, inplace=True)
df_lines_split['filename'] = df['filename'].repeat(df_lines_split.shape[0] // len(df)).reset_index(drop=True)
df_cleaned = df_lines_split[df_lines_split['line_str'].str.strip() != ""]

# %%
df_lines_split.to_csv(f'{file_path}/df_lines_split.csv', index=False)

# %%
def is_teacher_timestamp(text):
    return bool(re.search(r'teacher \d+.*\d+:\d+', text, re.IGNORECASE))
def is_transcribed_by_otter(text):
    return bool(re.search(r'transcribed by https://otter\.ai', text, re.IGNORECASE))

# %%
df_cleaned = df_cleaned.copy()
df_cleaned.loc[:, 'is_teacher_timestamp'] = df_cleaned['line_str'].apply(is_teacher_timestamp)
df_cleaned.loc[:, 'firstrow'] = df_cleaned.groupby('filename')['is_teacher_timestamp'].transform(
    lambda x: x.idxmax() == x.index).fillna(False).astype(int)
df_cleaned.loc[:, 'is_transcribed_by_otter'] = df_cleaned['line_str'].apply(is_transcribed_by_otter)
df_cleaned.loc[:, 'lastrow'] = df_cleaned['is_transcribed_by_otter'].apply(lambda x: 1 if x else 0)

# %%
df_cleaned.to_csv(f'{file_path}/df_cleaned.csv', index=False)

# %%
def keep_between_ones(group):
    start_idx = group['firstrow'].idxmax()  # First occurrence of 1 in the second column
    end_idx = group['lastrow'].idxmax()    # First occurrence of 1 in the third column
    return group.loc[start_idx:end_idx-1]
df_chopped = df_cleaned.groupby('filename', group_keys=False).apply(keep_between_ones)
df_chopped = df_chopped.drop(['firstrow', 'lastrow','is_teacher_timestamp','is_transcribed_by_otter'], axis=1)

# %%
df_chopped.to_csv(f'{file_path}/df_chopped.csv', index=False)

# %%
# Define a function to classify the rows based on the 'line_str'
def classify_line_str(line):
    if re.match(r'Teacher.*\d{2}:\d{2}', line):
        return 1
    elif re.match(r'.*\d{2}:\d{2}', line):
        return 2
    else:
        return np.nan
df_chopped['classification'] = df_chopped['line_str'].apply(classify_line_str)

# %%
# Define a function to extract the person (text before the timestamp) and timestamp
def extract_person_and_timestamp(line):
    # Use regex to match the format "[text] [timestamp]"
    match = re.search(r'(.+?)\s+(\d{2}:\d{2})', line)  # Adjusted to find any text before the timestamp
    if match:
        return match.group(1).strip(), match.group(2)
    else:
        return np.nan, np.nan
df_chopped['person'], df_chopped['timestamp'] = zip(*df_chopped.apply(
    lambda row: extract_person_and_timestamp(row['line_str']) if pd.notna(row['classification']) else (np.nan, np.nan), axis=1))

# %%
df_chopped['keep'] = df_chopped['classification'].apply(lambda x: 1 if pd.isna(x) else 0)
df_chopped['classification'] = df_chopped['classification'].ffill()
df_chopped['person'] = df_chopped['person'].ffill()
df_chopped['timestamp'] = df_chopped['timestamp'].ffill()
df_filtered = df_chopped[df_chopped['keep'] == 1]
df_filtered = df_filtered.drop(['keep'], axis=1)
df_filtered.reset_index(drop=True, inplace=True)

# %%
df_sentences = df_filtered.line_str.apply(lambda x: pd.Series(nltk.sent_tokenize(x))).stack().to_frame('sent_str')
df_sentences = df_sentences.reset_index(level=1, drop=True)
variables = ['filename', 'classification', 'person', 'timestamp','line_str']
for var in variables:
    df_sentences[var] = df_filtered[var].repeat(df_sentences.groupby(level=0).size()).values

# %%
#df_speaker = df_sentences[df_sentences['person'].str.contains('speaker', case=False, na=False)]

# %%
## Apply the conditions to locate the rows to be updated
#condition = (
#    (df_sentences['filename'] == "01_0101_G4_L03_transcript.txt") & 
#    (df_sentences['person'].str.contains('speaker', case=False, na=False))
#)
## Update the 'person' column
#df_sentences.loc[condition, 'person'] = "Teacher 01_0101"
## Update the 'classification' column to 1 for the same rows
#df_sentences.loc[condition, 'classification'] = 1

# %%
 df_sentences.head()
# Out:
#                                 sent_str                       filename  \
# 0                            You got it.  01_0101_G4_L03_transcript.txt
# 0              Nope which one which one?  01_0101_G4_L03_transcript.txt
# 0                                 Sorry.  01_0101_G4_L03_transcript.txt
# 0                     You guys are good.  01_0101_G4_L03_transcript.txt
# 1  Which planets revolve around the sun?  01_0101_G4_L04_transcript.txt
#
#    classification           person timestamp  \
# 0             1.0  Teacher 01_0101     47:59
# 0             1.0  Teacher 01_0101     47:59
# 0             1.0  Teacher 01_0101     47:59
# 0             1.0  Teacher 01_0101     47:59
# 1             1.0  Teacher 01_0101     36:14
#
#                                             line_str
# 0  You got it. Nope which one which one? Sorry. Y...
# 0  You got it. Nope which one which one? Sorry. Y...
# 0  You got it. Nope which one which one? Sorry. Y...
# 0  You got it. Nope which one which one? Sorry. Y...
# 1              Which planets revolve around the sun?

# %% [markdown]
# ### Tokenize Sentences

# %%
keep_whitespace = True
if keep_whitespace:
    # Return a tokenized copy of text
    # using NLTK's recommended word tokenizer.
    df_tokens = df_sentences.sent_str\
            .apply(lambda x: pd.Series(nltk.pos_tag(nltk.word_tokenize(x))))\
            .stack()\
            .to_frame('pos_tuple')
else:
    # Tokenize a string on whitespace (space, tab, newline).
    # In general, users should use the string ``split()`` method instead.
    # Returns fewer tokens.
    df_tokens = SENTS.sent_str\
            .apply(lambda x: pd.Series(nltk.pos_tag(nltk.WhitespaceTokenizer().tokenize(x))))\
            .stack()\
            .to_frame('pos_tuple')
df_tokens['pos'] = df_tokens.pos_tuple.apply(lambda x: x[1])
df_tokens['token_str'] = df_tokens.pos_tuple.apply(lambda x: x[0])
df_tokens['term_str'] = df_tokens.token_str.str.lower().str.replace(r"\W+", "", regex=True)
df_tokens['pos_group'] = df_tokens.pos.str[:2]

# %%
variables = ['filename', 'classification', 'person', 'timestamp','sent_str','line_str']
repeat_counts = df_sentences['sent_str'].apply(lambda x: len(nltk.word_tokenize(x)))
for var in variables:
    df_tokens[var] = np.repeat(df_sentences[var].values, repeat_counts)

# %%
df_tokens = df_tokens[df_tokens.term_str != '']

# %%
df_tokens.head(50)
# Out:
#            pos_tuple   pos token_str  term_str pos_group  \
# 0 0       (You, PRP)   PRP       You       you        PR
#   1       (got, VBD)   VBD       got       got        VB
#   2        (it, PRP)   PRP        it        it        PR
#   0       (Nope, NN)    NN      Nope      nope        NN
#   1     (which, WDT)   WDT     which     which        WD
#   2        (one, CD)    CD       one       one        CD
#   3     (which, WDT)   WDT     which     which        WD
#   4        (one, CD)    CD       one       one        CD
#   0     (Sorry, NNP)   NNP     Sorry     sorry        NN
#   0       (You, PRP)   PRP       You       you        PR
#   1      (guys, NNS)   NNS      guys      guys        NN
#   2       (are, VBP)   VBP       are       are        VB
#   3       (good, JJ)    JJ      good      good        JJ
# 1 0       (Here, RB)    RB      Here      here        RB
#   1        ('s, VBZ)   VBZ        's         s        VB
#   2     (your, PRP$)  PRP$      your      your        PR
#   3       (next, JJ)    JJ      next      next        JJ
#   4   (question, NN)    NN  question  question        NN
#   0      (Which, JJ)    JJ     Which     which        JJ
#   1   (planets, VBZ)   VBZ   planets   planets        VB
#   2   (revolve, VBP)   VBP   revolve   revolve        VB
#   3     (around, IN)    IN    around    around        IN
#   4        (the, DT)    DT       the       the        DT
#   5        (sun, NN)    NN       sun       sun        NN
#   0        (All, DT)    DT       All       all        DT
#   1     (except, IN)    IN    except    except        IN
#   2     (Earth, NNP)   NNP     Earth     earth        NN
#   4     (Earth, NNP)   NNP     Earth     earth        NN
#   5       (only, RB)    RB      only      only        RB
#   7        (the, DT)    DT       the       the        DT
#   8        (gas, NN)    NN       gas       gas        NN
#   9    (giants, NNS)   NNS    giants    giants        NN
#   11       (all, DT)    DT       all       all        DT
#   12  (planets, NNS)   NNS   planets   planets        NN
#   13  (revolve, VBP)   VBP   revolve   revolve        VB
#   14    (around, IN)    IN    around    around        IN
#   15       (the, DT)    DT       the       the        DT
#   16       (sun, NN)    NN       sun       sun        NN
# 2 0       (What, WP)    WP      What      what        WP
#   1      (does, VBZ)   VBZ      does      does        VB
#   2    (revolve, VB)    VB   revolve   revolve        VB
#   3       (mean, VB)    VB      mean      mean        VB
# 3 0        (It, PRP)   PRP        It        it        PR
#   1     (means, VBZ)   VBZ     means     means        VB
#   2        (go, VBP)   VBP        go        go        VB
#   3     (around, RB)    RB    around    around        RB
# 4 0      (Which, JJ)    JJ     Which     which        JJ
#   1   (planets, VBZ)   VBZ   planets   planets        VB
#   2   (revolve, VBP)   VBP   revolve   revolve        VB
#   3     (around, IN)    IN    around    around        IN
#
#                            filename  classification                person  \
# 0 0   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   3   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   4   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   0   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
#   3   01_0101_G4_L03_transcript.txt             1.0       Teacher 01_0101
# 1 0   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   0   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   5   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   0   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   5   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   7   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   8   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   9   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   11  01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   12  01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   13  01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   14  01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   15  01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   16  01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
# 2 0   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#   1   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#   2   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#   3   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 3 0   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#   1   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#   2   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#   3   01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 4 0   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0       Teacher 01_0101
#
#      timestamp                                           sent_str  \
# 0 0      47:59                                        You got it.
#   1      47:59                                        You got it.
#   2      47:59                                        You got it.
#   0      47:59                          Nope which one which one?
#   1      47:59                          Nope which one which one?
#   2      47:59                          Nope which one which one?
#   3      47:59                          Nope which one which one?
#   4      47:59                          Nope which one which one?
#   0      47:59                                             Sorry.
#   0      47:59                                 You guys are good.
#   1      47:59                                 You guys are good.
#   2      47:59                                 You guys are good.
#   3      47:59                                 You guys are good.
# 1 0      35:47                         Here's your next question.
#   1      35:47                         Here's your next question.
#   2      35:47                         Here's your next question.
#   3      35:47                         Here's your next question.
#   4      35:47                         Here's your next question.
#   0      35:47              Which planets revolve around the sun?
#   1      35:47              Which planets revolve around the sun?
#   2      35:47              Which planets revolve around the sun?
#   3      35:47              Which planets revolve around the sun?
#   4      35:47              Which planets revolve around the sun?
#   5      35:47              Which planets revolve around the sun?
#   0      35:47  All except Earth, Earth only, the gas giants, ...
#   1      35:47  All except Earth, Earth only, the gas giants, ...
#   2      35:47  All except Earth, Earth only, the gas giants, ...
#   4      35:47  All except Earth, Earth only, the gas giants, ...
#   5      35:47  All except Earth, Earth only, the gas giants, ...
#   7      35:47  All except Earth, Earth only, the gas giants, ...
#   8      35:47  All except Earth, Earth only, the gas giants, ...
#   9      35:47  All except Earth, Earth only, the gas giants, ...
#   11     35:47  All except Earth, Earth only, the gas giants, ...
#   12     35:47  All except Earth, Earth only, the gas giants, ...
#   13     35:47  All except Earth, Earth only, the gas giants, ...
#   14     35:47  All except Earth, Earth only, the gas giants, ...
#   15     35:47  All except Earth, Earth only, the gas giants, ...
#   16     35:47  All except Earth, Earth only, the gas giants, ...
# 2 0      36:06                            What does revolve mean?
#   1      36:06                            What does revolve mean?
#   2      36:06                            What does revolve mean?
#   3      36:06                            What does revolve mean?
# 3 0      36:07                                It means go around.
#   1      36:07                                It means go around.
#   2      36:07                                It means go around.
#   3      36:07                                It means go around.
# 4 0      36:14              Which planets revolve around the sun?
#   1      36:14              Which planets revolve around the sun?
#   2      36:14              Which planets revolve around the sun?
#   3      36:14              Which planets revolve around the sun?
#
#                                                line_str
# 0 0   You got it. Nope which one which one? Sorry. Y...
#   1   You got it. Nope which one which one? Sorry. Y...
#   2   You got it. Nope which one which one? Sorry. Y...
#   0   You got it. Nope which one which one? Sorry. Y...
#   1   You got it. Nope which one which one? Sorry. Y...
#   2   You got it. Nope which one which one? Sorry. Y...
#   3   You got it. Nope which one which one? Sorry. Y...
#   4   You got it. Nope which one which one? Sorry. Y...
#   0   You got it. Nope which one which one? Sorry. Y...
#   0   You got it. Nope which one which one? Sorry. Y...
#   1   You got it. Nope which one which one? Sorry. Y...
#   2   You got it. Nope which one which one? Sorry. Y...
#   3   You got it. Nope which one which one? Sorry. Y...
# 1 0   Here's your next question. Which planets revol...
#   1   Here's your next question. Which planets revol...
#   2   Here's your next question. Which planets revol...
#   3   Here's your next question. Which planets revol...
#   4   Here's your next question. Which planets revol...
#   0   Here's your next question. Which planets revol...
#   1   Here's your next question. Which planets revol...
#   2   Here's your next question. Which planets revol...
#   3   Here's your next question. Which planets revol...
#   4   Here's your next question. Which planets revol...
#   5   Here's your next question. Which planets revol...
#   0   Here's your next question. Which planets revol...
#   1   Here's your next question. Which planets revol...
#   2   Here's your next question. Which planets revol...
#   4   Here's your next question. Which planets revol...
#   5   Here's your next question. Which planets revol...
#   7   Here's your next question. Which planets revol...
#   8   Here's your next question. Which planets revol...
#   9   Here's your next question. Which planets revol...
#   11  Here's your next question. Which planets revol...
#   12  Here's your next question. Which planets revol...
#   13  Here's your next question. Which planets revol...
#   14  Here's your next question. Which planets revol...
#   15  Here's your next question. Which planets revol...
#   16  Here's your next question. Which planets revol...
# 2 0                             What does revolve mean?
#   1                             What does revolve mean?
#   2                             What does revolve mean?
#   3                             What does revolve mean?
# 3 0                                 It means go around.
#   1                                 It means go around.
#   2                                 It means go around.
#   3                                 It means go around.
# 4 0               Which planets revolve around the sun?
#   1               Which planets revolve around the sun?
#   2               Which planets revolve around the sun?
#   3               Which planets revolve around the sun?

# %% [markdown]
# ### Vocab Tables

# %%
# Teacher Vocab 
df_tokens_teacher = df_tokens[df_tokens['classification'] == 1]
vocab_teacher = df_tokens_teacher['term_str'].value_counts().to_frame('n')
vocab_teacher.index.name = 'term_str'
vocab_teacher['p'] = vocab_teacher['n'] / vocab_teacher['n'].sum()  # Probability of each term
vocab_teacher['i'] = -np.log2(vocab_teacher['p'])  # Information content
vocab_teacher['n_chars'] = vocab_teacher.index.str.len()  # Number of characters in each term

# %%
#Student Vocab
df_tokens_student = df_tokens[df_tokens['classification'] == 2]
vocab_student = df_tokens_student['term_str'].value_counts().to_frame('n')
vocab_student.index.name = 'term_str'
vocab_student['p'] = vocab_student['n'] / vocab_student['n'].sum()  # Probability of each term
vocab_student['i'] = -np.log2(vocab_student['p'])  # Information content
vocab_student['n_chars'] = vocab_student.index.str.len()  # Number of characters in each term
vocab_student.head()
# Out:
#              n         p         i  n_chars
# term_str
# the       1627  0.045186  4.467991        3
# it        1184  0.032882  4.926536        2
# i          899  0.024967  5.323812        1
# you        773  0.021468  5.541665        3
# and        753  0.020913  5.579484        3

# %%
vocab_teacher.head(20)
# Out:
#              n         p         i  n_chars
# term_str
# you       6528  0.040610  4.622016        3
# the       5288  0.032896  4.925935        3
# it        4202  0.026140  5.257581        2
# to        4196  0.026103  5.259642        2
# i         3207  0.019950  5.647433        1
# and       3003  0.018681  5.742253        3
# that      2932  0.018240  5.776772        4
# a         2588  0.016100  5.956819        1
# s         2582  0.016062  5.960168        1
# we        2536  0.015776  5.986102        2
# so        2471  0.015372  6.023562        2
# what      2090  0.013002  6.265154        4
# okay      2031  0.012635  6.306467        4
# of        1993  0.012398  6.333715        2
# is        1922  0.011957  6.386049        2
# your      1917  0.011925  6.389807        4
# do        1892  0.011770  6.408745        2
# re        1652  0.010277  6.604443        2
# in        1610  0.010016  6.641596        2
# right     1503  0.009350  6.740812        5

# %%
vocab_student.head(20)
# Out:
#              n         p         i  n_chars
# term_str
# the       1627  0.045186  4.467991        3
# it        1184  0.032882  4.926536        2
# i          899  0.024967  5.323812        1
# you        773  0.021468  5.541665        3
# and        753  0.020913  5.579484        3
# to         714  0.019829  5.656210        2
# a          672  0.018663  5.743672        1
# s          631  0.017524  5.834494        1
# that       593  0.016469  5.924101        4
# we         565  0.015691  5.993883        2
# like       527  0.014636  6.094331        4
# is         439  0.012192  6.357913        2
# of         437  0.012137  6.364500        2
# do         376  0.010442  6.581401        2
# so         373  0.010359  6.592958        2
# this       331  0.009193  6.765302        4
# in         322  0.008943  6.805073        2
# can        282  0.007832  6.996438        3
# nt         277  0.007693  7.022248        2
# what       275  0.007637  7.032702        4

# %%
df_tokens_student.head(50)
# Out:
#                 pos_tuple  pos     token_str      term_str pos_group  \
# 2  0           (What, WP)   WP          What          what        WP
#    1          (does, VBZ)  VBZ          does          does        VB
#    2        (revolve, VB)   VB       revolve       revolve        VB
#    3           (mean, VB)   VB          mean          mean        VB
# 3  0            (It, PRP)  PRP            It            it        PR
#    1         (means, VBZ)  VBZ         means         means        VB
#    2            (go, VBP)  VBP            go            go        VB
#    3         (around, RB)   RB        around        around        RB
# 5  0           (Yay, NNP)  NNP           Yay           yay        NN
#    2         (varied, JJ)   JJ        varied        varied        JJ
#    3      (respones, NNS)  NNS      respones      respones        NN
# 6  0             (I, PRP)  PRP             I             i        PR
#    1           (was, VBD)  VBD           was           was        VB
#    2            (n't, RB)   RB           n't            nt        RB
#    3           (here, RB)   RB          here          here        RB
#    4            (but, CC)   CC           but           but        CC
#    5             (I, PRP)  PRP             I             i        PR
#    6           (got, VBD)  VBD           got           got        VB
#    7            (it, PRP)  PRP            it            it        PR
#    8          (right, RB)   RB         right         right        RB
# 8  0            (All, DT)   DT           All           all        DT
#    1             (of, IN)   IN            of            of        IN
#    2          (them, PRP)  PRP          them          them        PR
# 11 0             (Oh, UH)   UH            Oh            oh        UH
#    1             (no, DT)   DT            no            no        DT
# 12 0            (We, PRP)  PRP            We            we        PR
#    1        (already, RB)   RB       already       already        RB
#    2          (know, VBP)  VBP          know          know        VB
#    3  (____________, NNS)  NNS  ____________  ____________        NN
# 15 0           (Star, NN)   NN          Star          star        NN
# 17 1        (Varied, NNP)  NNP        Varied        varied        NN
#    2     (responses, NNS)  NNS     responses     responses        NN
# 19 0            (We, PRP)  PRP            We            we        PR
#    1        (already, RB)   RB       already       already        RB
#    2          (know, VBP)  VBP          know          know        VB
#    3           (that, DT)   DT          that          that        DT
# 20 1        (Varied, NNP)  NNP        Varied        varied        NN
#    2     (responses, NNS)  NNS     responses     responses        NN
# 21 0            (Do, VBP)  VBP            Do            do        VB
#    1            (we, PRP)  PRP            we            we        PR
#    2            (get, VB)   VB           get           get        VB
#    3            (any, DT)   DT           any           any        DT
#    4           (hard, JJ)   JJ          hard          hard        JJ
#    5     (questions, NNS)  NNS     questions     questions        NN
# 24 0          (Solar, JJ)   JJ         Solar         solar        JJ
#    1         (system, NN)   NN        system        system        NN
# 26 0             (I, PRP)  PRP             I             i        PR
#    1           (just, RB)   RB          just          just        RB
#    2          (about, IN)   IN         about         about        IN
#    3        (picked, VBD)  VBD        picked        picked        VB
#
#                            filename  classification                person  \
# 2  0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 3  0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 5  0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    2  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    3  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 6  0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    4  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    5  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    6  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    7  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    8  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 8  0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    1  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    2  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 11 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 12 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 15 0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 17 1  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    2  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 19 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 20 1  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    2  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 21 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    4  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    5  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
# 24 0  01_0101_G4_L04_transcript.txt             2.0           Whole Class
#    1  01_0101_G4_L04_transcript.txt             2.0           Whole Class
# 26 0  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    1  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    2  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#    3  01_0101_G4_L04_transcript.txt             2.0  Unidentified Student
#
#      timestamp                           sent_str  \
# 2  0     36:06            What does revolve mean?
#    1     36:06            What does revolve mean?
#    2     36:06            What does revolve mean?
#    3     36:06            What does revolve mean?
# 3  0     36:07                It means go around.
#    1     36:07                It means go around.
#    2     36:07                It means go around.
#    3     36:07                It means go around.
# 5  0     36:17              Yay (varied respones)
#    2     36:17              Yay (varied respones)
#    3     36:17              Yay (varied respones)
# 6  0     36:23  I wasn't here but I got it right!
#    1     36:23  I wasn't here but I got it right!
#    2     36:23  I wasn't here but I got it right!
#    3     36:23  I wasn't here but I got it right!
#    4     36:23  I wasn't here but I got it right!
#    5     36:23  I wasn't here but I got it right!
#    6     36:23  I wasn't here but I got it right!
#    7     36:23  I wasn't here but I got it right!
#    8     36:23  I wasn't here but I got it right!
# 8  0     36:28                       All of them!
#    1     36:28                       All of them!
#    2     36:28                       All of them!
# 11 0     36:51                             Oh no!
#    1     36:51                             Oh no!
# 12 0     36:51       We already know ____________
#    1     36:51       We already know ____________
#    2     36:51       We already know ____________
#    3     36:51       We already know ____________
# 15 0     37:38                              Star.
# 17 1     37:44                 (Varied responses)
#    2     37:44                 (Varied responses)
# 19 0     38:05              We already know that.
#    1     38:05              We already know that.
#    2     38:05              We already know that.
#    3     38:05              We already know that.
# 20 1     38:07                 (Varied responses)
#    2     38:07                 (Varied responses)
# 21 0     38:13      Do we get any hard questions?
#    1     38:13      Do we get any hard questions?
#    2     38:13      Do we get any hard questions?
#    3     38:13      Do we get any hard questions?
#    4     38:13      Do we get any hard questions?
#    5     38:13      Do we get any hard questions?
# 24 0     39:11                      Solar system!
#    1     39:11                      Solar system!
# 26 0     39:14  I just about picked the rotation.
#    1     39:14  I just about picked the rotation.
#    2     39:14  I just about picked the rotation.
#    3     39:14  I just about picked the rotation.
#
#                                 line_str
# 2  0             What does revolve mean?
#    1             What does revolve mean?
#    2             What does revolve mean?
#    3             What does revolve mean?
# 3  0                 It means go around.
#    1                 It means go around.
#    2                 It means go around.
#    3                 It means go around.
# 5  0               Yay (varied respones)
#    2               Yay (varied respones)
#    3               Yay (varied respones)
# 6  0   I wasn't here but I got it right!
#    1   I wasn't here but I got it right!
#    2   I wasn't here but I got it right!
#    3   I wasn't here but I got it right!
#    4   I wasn't here but I got it right!
#    5   I wasn't here but I got it right!
#    6   I wasn't here but I got it right!
#    7   I wasn't here but I got it right!
#    8   I wasn't here but I got it right!
# 8  0                        All of them!
#    1                        All of them!
#    2                        All of them!
# 11 0                              Oh no!
#    1                              Oh no!
# 12 0        We already know ____________
#    1        We already know ____________
#    2        We already know ____________
#    3        We already know ____________
# 15 0                              Star.
# 17 1                  (Varied responses)
#    2                  (Varied responses)
# 19 0               We already know that.
#    1               We already know that.
#    2               We already know that.
#    3               We already know that.
# 20 1                  (Varied responses)
#    2                  (Varied responses)
# 21 0       Do we get any hard questions?
#    1       Do we get any hard questions?
#    2       Do we get any hard questions?
#    3       Do we get any hard questions?
#    4       Do we get any hard questions?
#    5       Do we get any hard questions?
# 24 0                      Solar system!
#    1                      Solar system!
# 26 0  I just about picked the rotation.
#    1  I just about picked the rotation.
#    2  I just about picked the rotation.
#    3  I just about picked the rotation.

# %%
df_tokens_teacher.head(50)
# Out:
#            pos_tuple   pos token_str  term_str pos_group  \
# 0 0       (You, PRP)   PRP       You       you        PR
#   1       (got, VBD)   VBD       got       got        VB
#   2        (it, PRP)   PRP        it        it        PR
#   0       (Nope, NN)    NN      Nope      nope        NN
#   1     (which, WDT)   WDT     which     which        WD
#   2        (one, CD)    CD       one       one        CD
#   3     (which, WDT)   WDT     which     which        WD
#   4        (one, CD)    CD       one       one        CD
#   0     (Sorry, NNP)   NNP     Sorry     sorry        NN
#   0       (You, PRP)   PRP       You       you        PR
#   1      (guys, NNS)   NNS      guys      guys        NN
#   2       (are, VBP)   VBP       are       are        VB
#   3       (good, JJ)    JJ      good      good        JJ
# 1 0       (Here, RB)    RB      Here      here        RB
#   1        ('s, VBZ)   VBZ        's         s        VB
#   2     (your, PRP$)  PRP$      your      your        PR
#   3       (next, JJ)    JJ      next      next        JJ
#   4   (question, NN)    NN  question  question        NN
#   0      (Which, JJ)    JJ     Which     which        JJ
#   1   (planets, VBZ)   VBZ   planets   planets        VB
#   2   (revolve, VBP)   VBP   revolve   revolve        VB
#   3     (around, IN)    IN    around    around        IN
#   4        (the, DT)    DT       the       the        DT
#   5        (sun, NN)    NN       sun       sun        NN
#   0        (All, DT)    DT       All       all        DT
#   1     (except, IN)    IN    except    except        IN
#   2     (Earth, NNP)   NNP     Earth     earth        NN
#   4     (Earth, NNP)   NNP     Earth     earth        NN
#   5       (only, RB)    RB      only      only        RB
#   7        (the, DT)    DT       the       the        DT
#   8        (gas, NN)    NN       gas       gas        NN
#   9    (giants, NNS)   NNS    giants    giants        NN
#   11       (all, DT)    DT       all       all        DT
#   12  (planets, NNS)   NNS   planets   planets        NN
#   13  (revolve, VBP)   VBP   revolve   revolve        VB
#   14    (around, IN)    IN    around    around        IN
#   15       (the, DT)    DT       the       the        DT
#   16       (sun, NN)    NN       sun       sun        NN
# 4 0      (Which, JJ)    JJ     Which     which        JJ
#   1   (planets, VBZ)   VBZ   planets   planets        VB
#   2   (revolve, VBP)   VBP   revolve   revolve        VB
#   3     (around, IN)    IN    around    around        IN
#   4        (the, DT)    DT       the       the        DT
#   5        (sun, NN)    NN       sun       sun        NN
# 7 0   (Alright, NNP)   NNP   Alright   alright        NN
#   2         (so, RB)    RB        so        so        RB
#   3     (which, WDT)   WDT     which     which        WD
#   4   (planets, NNS)   NNS   planets   planets        NN
#   5        (go, VBP)   VBP        go        go        VB
#   6     (around, IN)    IN    around    around        IN
#
#                            filename  classification           person  \
# 0 0   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   0   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   3   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   4   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   0   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   0   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
#   3   01_0101_G4_L03_transcript.txt             1.0  Teacher 01_0101
# 1 0   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   0   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   5   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   0   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   5   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   7   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   8   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   9   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   11  01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   12  01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   13  01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   14  01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   15  01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   16  01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
# 4 0   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   1   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   5   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
# 7 0   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   2   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   3   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   4   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   5   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#   6   01_0101_G4_L04_transcript.txt             1.0  Teacher 01_0101
#
#      timestamp                                           sent_str  \
# 0 0      47:59                                        You got it.
#   1      47:59                                        You got it.
#   2      47:59                                        You got it.
#   0      47:59                          Nope which one which one?
#   1      47:59                          Nope which one which one?
#   2      47:59                          Nope which one which one?
#   3      47:59                          Nope which one which one?
#   4      47:59                          Nope which one which one?
#   0      47:59                                             Sorry.
#   0      47:59                                 You guys are good.
#   1      47:59                                 You guys are good.
#   2      47:59                                 You guys are good.
#   3      47:59                                 You guys are good.
# 1 0      35:47                         Here's your next question.
#   1      35:47                         Here's your next question.
#   2      35:47                         Here's your next question.
#   3      35:47                         Here's your next question.
#   4      35:47                         Here's your next question.
#   0      35:47              Which planets revolve around the sun?
#   1      35:47              Which planets revolve around the sun?
#   2      35:47              Which planets revolve around the sun?
#   3      35:47              Which planets revolve around the sun?
#   4      35:47              Which planets revolve around the sun?
#   5      35:47              Which planets revolve around the sun?
#   0      35:47  All except Earth, Earth only, the gas giants, ...
#   1      35:47  All except Earth, Earth only, the gas giants, ...
#   2      35:47  All except Earth, Earth only, the gas giants, ...
#   4      35:47  All except Earth, Earth only, the gas giants, ...
#   5      35:47  All except Earth, Earth only, the gas giants, ...
#   7      35:47  All except Earth, Earth only, the gas giants, ...
#   8      35:47  All except Earth, Earth only, the gas giants, ...
#   9      35:47  All except Earth, Earth only, the gas giants, ...
#   11     35:47  All except Earth, Earth only, the gas giants, ...
#   12     35:47  All except Earth, Earth only, the gas giants, ...
#   13     35:47  All except Earth, Earth only, the gas giants, ...
#   14     35:47  All except Earth, Earth only, the gas giants, ...
#   15     35:47  All except Earth, Earth only, the gas giants, ...
#   16     35:47  All except Earth, Earth only, the gas giants, ...
# 4 0      36:14              Which planets revolve around the sun?
#   1      36:14              Which planets revolve around the sun?
#   2      36:14              Which planets revolve around the sun?
#   3      36:14              Which planets revolve around the sun?
#   4      36:14              Which planets revolve around the sun?
#   5      36:14              Which planets revolve around the sun?
# 7 0      36:26       Alright, so which planets go around the sun?
#   2      36:26       Alright, so which planets go around the sun?
#   3      36:26       Alright, so which planets go around the sun?
#   4      36:26       Alright, so which planets go around the sun?
#   5      36:26       Alright, so which planets go around the sun?
#   6      36:26       Alright, so which planets go around the sun?
#
#                                                line_str
# 0 0   You got it. Nope which one which one? Sorry. Y...
#   1   You got it. Nope which one which one? Sorry. Y...
#   2   You got it. Nope which one which one? Sorry. Y...
#   0   You got it. Nope which one which one? Sorry. Y...
#   1   You got it. Nope which one which one? Sorry. Y...
#   2   You got it. Nope which one which one? Sorry. Y...
#   3   You got it. Nope which one which one? Sorry. Y...
#   4   You got it. Nope which one which one? Sorry. Y...
#   0   You got it. Nope which one which one? Sorry. Y...
#   0   You got it. Nope which one which one? Sorry. Y...
#   1   You got it. Nope which one which one? Sorry. Y...
#   2   You got it. Nope which one which one? Sorry. Y...
#   3   You got it. Nope which one which one? Sorry. Y...
# 1 0   Here's your next question. Which planets revol...
#   1   Here's your next question. Which planets revol...
#   2   Here's your next question. Which planets revol...
#   3   Here's your next question. Which planets revol...
#   4   Here's your next question. Which planets revol...
#   0   Here's your next question. Which planets revol...
#   1   Here's your next question. Which planets revol...
#   2   Here's your next question. Which planets revol...
#   3   Here's your next question. Which planets revol...
#   4   Here's your next question. Which planets revol...
#   5   Here's your next question. Which planets revol...
#   0   Here's your next question. Which planets revol...
#   1   Here's your next question. Which planets revol...
#   2   Here's your next question. Which planets revol...
#   4   Here's your next question. Which planets revol...
#   5   Here's your next question. Which planets revol...
#   7   Here's your next question. Which planets revol...
#   8   Here's your next question. Which planets revol...
#   9   Here's your next question. Which planets revol...
#   11  Here's your next question. Which planets revol...
#   12  Here's your next question. Which planets revol...
#   13  Here's your next question. Which planets revol...
#   14  Here's your next question. Which planets revol...
#   15  Here's your next question. Which planets revol...
#   16  Here's your next question. Which planets revol...
# 4 0               Which planets revolve around the sun?
#   1               Which planets revolve around the sun?
#   2               Which planets revolve around the sun?
#   3               Which planets revolve around the sun?
#   4               Which planets revolve around the sun?
#   5               Which planets revolve around the sun?
# 7 0        Alright, so which planets go around the sun?
#   2        Alright, so which planets go around the sun?
#   3        Alright, so which planets go around the sun?
#   4        Alright, so which planets go around the sun?
#   5        Alright, so which planets go around the sun?
#   6        Alright, so which planets go around the sun?

# %%
df_tokens.to_csv(f'{file_path}/df_tokens.csv', index=False)
